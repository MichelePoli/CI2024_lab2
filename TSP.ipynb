# %%
import pandas as pd 
import random
  
from itertools import product
import numpy as np

from icecream import ic
from matplotlib import pyplot as plt
from itertools import accumulate
from scipy.spatial.distance import cdist 
from geopy.distance import geodesic
from itertools import combinations

# %%
# Set the variable to choose the dataset
country = "Italy"  # Change this to "China", "Russia", "US", or "Vanuatu" as needed

# Load the corresponding CSV file based on the country variable
cities = pd.read_csv(f'cities/{country.lower()}.csv', header=None, names=['City', 'lat', 'lon'])

DIST_MATRIX = np.zeros((len(cities), len(cities)))
for c1, c2 in combinations(cities.itertuples(), 2):
    DIST_MATRIX[c1.Index, c2.Index] = DIST_MATRIX[c2.Index, c1.Index] = geodesic(
        (c1.lat, c1.lon), (c2.lat, c2.lon)
    ).km
cities
# Out:
#                      City    lat    lon
# 0                  Ancona  43.60  13.50
# 1                  Andria  41.23  16.29
# 2                    Bari  41.12  16.87
# 3                 Bergamo  45.70   9.67
# 4                 Bologna  44.50  11.34
# 5                 Bolzano  46.50  11.35
# 6                 Brescia  45.55  10.22
# 7                Cagliari  39.22   9.10
# 8                 Catania  37.50  15.08
# 9                 Ferrara  44.84  11.61
# 10               Florence  43.78  11.24
# 11                 Foggia  41.47  15.55
# 12                  Forlì  44.22  12.03
# 13                  Genoa  44.42   8.93
# 14  Giugliano in Campania  40.93  14.19
# 15                 Latina  41.47  12.89
# 16                Leghorn  43.55  10.30
# 17                Messina  38.19  15.55
# 18                  Milan  45.47   9.17
# 19                 Modena  44.65  10.92
# 20                  Monza  45.58   9.27
# 21                 Naples  40.85  14.27
# 22                 Novara  45.45   8.62
# 23                  Padua  45.41  11.87
# 24                Palermo  38.12  13.36
# 25                  Parma  44.81  10.32
# 26                Perugia  43.11  12.39
# 27                Pescara  42.46  14.21
# 28               Piacenza  45.06   9.68
# 29                  Prato  43.89  11.09
# 30                Ravenna  44.42  12.21
# 31     Reggio di Calabria  38.11  15.65
# 32     Reggio nell'Emilia  44.71  10.63
# 33                 Rimini  44.06  12.57
# 34                   Rome  41.89  12.50
# 35                Salerno  40.68  14.77
# 36                Sassari  40.73   8.56
# 37               Syracuse  37.07  15.29
# 38                Taranto  40.48  17.24
# 39                  Terni  42.57  12.65
# 40                 Trento  46.08  11.12
# 41                Trieste  45.65  13.77
# 42                  Turin  45.08   7.68
# 43                 Venice  45.43  12.33
# 44                 Verona  45.44  10.99
# 45                Vicenza  45.55  11.54

# %%
city_list = cities['City'].values.tolist()  # List of city names
city_indices = {city: index for index, city in enumerate(city_list)}
#If city_list is ['Rome', 'Milan', 'Naples'], then city_indices would be {'Rome': 0, 'Milan': 1, 'Naples': 2}.

# %%
#create a route with a greedy algorithm (start with a random city and then choice the nearest city)
def create_greedy_route(city_list, DIST_MATRIX, city_indices):
    """Create a route using a greedy approach, starting from a random city and visiting the nearest unvisited city."""
    # Step 1: Choose a random starting city
    start_city = random.choice(city_list)
    route = [start_city]
    unvisited = set(city_list) - {start_city} #set of unvisited cities

    # Step 2: Iteratively add the nearest unvisited city to the route
    current_city = start_city
    while unvisited:
        nearest_city = min(unvisited, key=lambda city: DIST_MATRIX[city_indices[current_city], city_indices[city]])
        route.append(nearest_city)
        unvisited.remove(nearest_city)
        current_city = nearest_city

    # Step 3: Close the loop by returning to the start city
    route.append(start_city)
    return route



def initial_population(pop_size, city_list, DIST_MATRIX, city_indices):
    """Generate an initial population of routes."""
    population = [create_greedy_route(city_list, DIST_MATRIX, city_indices) for _ in range(pop_size)]
    return population

#the cost needs to include the last step, from the last city back to the first city
#the number of steps corresponds to the number of cities
#the cost is the sum of the distances between the cities in the route

def route_distance(route, DIST_MATRIX, city_list):
    """Calculate the total distance of the route based on the distance matrix."""
    distance = 0
    for i in range(len(route)):
        start_city = route[i]
        end_city = route[(i + 1) % len(route)] #modulo to connect the last city with the first city #i+1 % len(route) -> i+1 % 5 = 1, 2, 3, 4, 0
        distance += DIST_MATRIX[city_list.index(start_city), city_list.index(end_city)]
    return distance

# %%
# Parameters
pop_size = 2
max_generations = 1000  # Define how many generations to run

city_list= cities['City'].values.tolist() #only the names of the cities. cities['City'].values.tolist()

##Now try to create a population of two routes
population = initial_population(pop_size, city_list, DIST_MATRIX, city_indices) #2 parents
print("Initial population", population)
routeDistance0= route_distance(population[0], DIST_MATRIX, city_list)
print("Route Distance 0:", routeDistance0)
routeDistance1= route_distance(population[1], DIST_MATRIX, city_list)
print("Route Distance 1:", routeDistance1)
# Out:
# Initial population [['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'], ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']]
# Route Distance 0: 4576.195155974608
# Route Distance 1: 4662.176125656765

# %%
#before mutation (inversion mutation) and then crossover (inver over)

# Start with an "inversion mutation":
# Select Two Points in the route randomly. These two points will define the segment of the route to be reversed.
# Reverse the Segment between these points.
# Return the Mutated Route.
def inversion_mutation(route):
    """Apply inversion mutation to a route by reversing a random segment of the route."""
    # Step 1: Choose two random indices in the route
    start, end = sorted(random.sample(range(len(route)), 2))
    
    # Step 2: Reverse the cities between the two indices
    route[start:end+1] = reversed(route[start:end+1])
    
    return route

# %%
#then we apply the inver over crossover method
#The goal of this method is to combine two parent routes while trying to preserve the sequence of edges from one parent as much as possible, by performing an inversion mutation that integrates edges from the second parent.

def inver_over_crossover(parent1, parent2):
    """Perform Inver Over crossover between two parent routes."""
    child = parent1[:-1]  # Exclude the last city to avoid duplication, when later appending the starting city at the end of the child route.
    current_index = random.randint(0, len(child) - 2) #a random index is selected from the child route to start the crossover process
    
    while True: #This loop continues until the entire route has been processed.
        current_city = child[current_index] #The current_city is determined from the child using current_index.
        next_city_in_parent2 = get_next_city_in_parent(parent2, current_city) #The next city in parent2 after current_city is obtained using the helper function get_next_city_in_parent.

        if next_city_in_parent2 == child[(current_index + 1) % len(child)]: #If the next_city_in_parent2 is the same as the next city in the child, the algorithm continues to the next index. This avoids duplicating edges in the child route.
            current_index = (current_index + 1) % (len(child) - 1)
            if current_index == 0:
                break
            continue
        
        target_index = child.index(next_city_in_parent2) #The index of next_city_in_parent2 in the child is found. This index will be used to determine where to perform the inversion mutation.
        if target_index > current_index: #If target_index is greater than current_index, it means the segment between these two indices can be reversed:
            child[current_index + 1:target_index + 1] = reversed(child[current_index + 1:target_index + 1]) 
        else: #If target_index is less than current_index, it indicates that the segment wraps around the end of the list, and that segment is reversed:
            sub_segment = child[current_index + 1:] + child[:target_index + 1] #The sub_segment is created by concatenating the two segments.
            sub_segment = list(reversed(sub_segment)) #The sub_segment is reversed.
            child[current_index + 1:], child[:target_index + 1] = sub_segment[:len(child) - current_index - 1], sub_segment[len(child) - current_index - 1:] #The reversed sub_segment is split back into two segments and assigned to the child route.

        current_index = (current_index + 1) % (len(child) - 1) #Move to the next index for the next iteration. The modulo operation ensures it wraps around.
        if current_index == 0:
            break

    child.append(child[0])  # Close the route by adding the starting city at the end
    return child

def get_next_city_in_parent(parent, city):
    """Get the next city in a parent route after the specified city, wrapping around if necessary."""
    idx = parent.index(city)
    return parent[(idx + 1) % len(parent)]

# Multiple Iterations to Adjust the Route: Each iteration in the while-loop either:
# Moves to the next city if the next edge already exists in the child, or Performs a reversal if the edge from parent2 is missing in the child.
# By repeating the check across multiple cities, the child route can incorporate as many edges as possible from parent2, effectively combining elements from both parents.

# %%
#the idea is to generate a child from the two parents and then replace one of the parents or both with the child if the child is better than the parent. 

# Initialize variables to track the best solution
best_route = None
best_distance = float('inf')

# Start evolving the population
for generation in range(max_generations):
    print(f"\n--- Generation {generation + 1} ---")
    
    # Evaluate the current population
    route_distances = [route_distance(route, DIST_MATRIX, city_list) for route in population]
    
    # Find the best route in the current population
    for i, route in enumerate(population):
        distance = route_distances[i]
        print(f"Route {i}: {route} | Distance: {distance}")
        
        # Update the best route if this one is better
        if distance < best_distance:
            best_distance = distance
            best_route = route
    
    # Apply inversion mutation on both two routes
    mutated_route = inversion_mutation(population[0].copy()) 
    mutated_route_distance = route_distance(mutated_route, DIST_MATRIX, city_list)
    print("Mutated Route:", mutated_route)
    print("Mutated Route Distance:", mutated_route_distance)

    if mutated_route_distance < route_distances[0]: # Replace the original route if the mutated one is better
        print("The mutated route is better than the original route.")
        population[0] = mutated_route

    mutated_route = inversion_mutation(population[1].copy()) 
    mutated_route_distance = route_distance(mutated_route, DIST_MATRIX, city_list)
    print("Mutated Route:", mutated_route)
    print("Mutated Route Distance:", mutated_route_distance)

    if mutated_route_distance < route_distances[1]: 
        print("The mutated route is better than the original route.")
        population[1] = mutated_route
    
    # Apply crossover to create a child route
    child = inver_over_crossover(population[0], population[1])
    child_distance = route_distance(child, DIST_MATRIX, city_list)
    print("Child Route:", child)
    print("Child Route Distance:", child_distance)


    # Replace one of the parent routes with the child if the child is better
    if child_distance < min(route_distances):
        index = route_distances.index(max(route_distances))
        population[index] = child
        print("The child route is better than one of the parent routes.")
        
# Print the best solution found
print("\n--- Best Solution Found ---")
print("Best Route:", best_route)
print("Best Route Distance:", best_distance)
# larger max_generation value leads to better results
#final cost is the distance of the best route found. number of steps corresponds to the number of max_generations.
# Out:
# --- Generation 1 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4854.7488619549285
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Piacenza', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 5701.835495327372
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 2 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Venice', 'Trieste', 'Pescara', 'Sassari', 'Cagliari', 'Palermo', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 6115.1589941211
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Padua', 'Vicenza', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 6375.777535283195
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 3 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 5231.488342903085
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Cagliari', 'Palermo', 'Syracuse', 'Catania', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 5709.945174650225
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 4 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4817.673876817659
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Pescara', 'Sassari', 'Cagliari', 'Palermo', 'Syracuse', 'Catania', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 5038.400050736058
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 5 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bolzano', 'Trento', 'Venice', 'Trieste', 'Pescara', 'Sassari', 'Cagliari', 'Palermo', 'Syracuse', 'Catania', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Piacenza']
# Mutated Route Distance: 5757.574995072444
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Padua', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 5052.590375841172
# Child Route: ['Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Trento', 'Bolzano', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse']
# Child Route Distance: 4699.241021616994
#
# --- Generation 6 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4688.46653753354
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Piacenza', 'Parma', "Reggio nell'Emilia", 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 6264.0150367116485
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 7 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 5083.338193398899
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 6560.893208115562
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 8 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4668.854572247798
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 4856.790513582491
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 9 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4816.041882497708
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 5559.52799068516
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 10 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4859.245156404414
# Mutated Route: ['Turin', 'Novara', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 5028.7969572091815
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 11 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Pescara', 'Sassari', 'Cagliari', 'Palermo', 'Syracuse', 'Catania', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4790.824452045119
# Mutated Route: ['Turin', 'Venice', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 5102.813277469571
# Child Route: ['Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza']
# Child Route Distance: 4662.176125656765
#
# --- Generation 12 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4676.6476041243495
# Mutated Route: ['Novara', 'Turin', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 4828.251929230778
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 13 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Venice', 'Trieste', 'Pescara', 'Sassari', 'Cagliari', 'Palermo', 'Syracuse', 'Catania', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4737.588625172479
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Prato', 'Leghorn', 'Genoa', 'Piacenza', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 4895.439592303731
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 14 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Trento', 'Venice', 'Trieste', 'Pescara', 'Sassari', 'Cagliari', 'Palermo', 'Syracuse', 'Catania', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4844.883296989035
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Syracuse', 'Catania', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 5304.342664615505
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 15 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Catania', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 6376.048902367629
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 5283.517677531096
# Child Route: ['Venice', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Venice']
# Child Route Distance: 4729.3700959449
#
# --- Generation 16 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 5817.989525152186
# Mutated Route: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Catania', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Padua', 'Vicenza', 'Verona', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin']
# Mutated Route Distance: 6527.411049678108
# Child Route: ['Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Venice', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin', 'Novara']
# Child Route Distance: 5016.350405709363
#
# --- Generation 17 ---
# Route 0: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza'] | Distance: 4576.195155974608
# Route 1: ['Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Bolzano', 'Trento', 'Turin'] | Distance: 4662.176125656765
# Mutated Route: ['Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Padua', 'Vicenza', 'Verona', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Forlì', 'Florence', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Trieste', 'Venice', 'Trento', 'Bolzano', 'Piacenza']
# Mutated Route Distance: 4721.6425176993735
# ...
# Mutated Route Distance: 5399.512462490406
# Child Route: ['Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano', 'Brescia', 'Bergamo', 'Monza']
# Child Route Distance: 4512.2162411827785
#
# --- Generation 996 ---
# Route 0: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Trento', 'Bolzano', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"] | Distance: 4505.8017130027165
# Route 1: ['Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano'] | Distance: 4512.216241182778
# Mutated Route: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Vicenza', 'Bolzano', 'Trento', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"]
# Mutated Route Distance: 5119.810624087403
# Mutated Route: ['Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano']
# Mutated Route Distance: 4885.539318725176
# Child Route: ['Bolzano', 'Trento', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Bolzano']
# Child Route Distance: 4505.8017130027165
#
# --- Generation 997 ---
# Route 0: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Trento', 'Bolzano', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"] | Distance: 4505.8017130027165
# Route 1: ['Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano'] | Distance: 4512.216241182778
# Mutated Route: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Trento', 'Bolzano', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"]
# Mutated Route Distance: 4589.465995959854
# Mutated Route: ['Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano']
# Mutated Route Distance: 4604.495466183983
# Child Route: ['Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano', 'Brescia', 'Bergamo', 'Monza']
# Child Route Distance: 4512.2162411827785
#
# --- Generation 998 ---
# Route 0: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Trento', 'Bolzano', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"] | Distance: 4505.8017130027165
# Route 1: ['Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano'] | Distance: 4512.216241182778
# Mutated Route: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Salerno', 'Naples', 'Giugliano in Campania', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Trento', 'Bolzano', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"]
# Mutated Route Distance: 4581.430838434361
# Mutated Route: ['Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Trento', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Bolzano']
# Mutated Route Distance: 5289.191044737987
# Child Route: ['Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Bolzano', 'Trento', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì']
# Child Route Distance: 4505.801713002717
#
# --- Generation 999 ---
# Route 0: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Trento', 'Bolzano', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"] | Distance: 4505.8017130027165
# Route 1: ['Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano'] | Distance: 4512.216241182778
# Mutated Route: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Milan', 'Novara', 'Turin', 'Genoa', 'Monza', 'Bergamo', 'Brescia', 'Trento', 'Bolzano', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"]
# Mutated Route Distance: 4708.091895831599
# Mutated Route: ['Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano']
# Mutated Route Distance: 5638.654305954627
# Child Route: ['Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna']
# Child Route Distance: 4512.216241182779
#
# --- Generation 1000 ---
# Route 0: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Trento', 'Bolzano', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"] | Distance: 4505.8017130027165
# Route 1: ['Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano'] | Distance: 4512.216241182778
# Mutated Route: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Padua', 'Vicenza', 'Bolzano', 'Trento', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"]
# Mutated Route Distance: 5546.691346814353
# Mutated Route: ['Bolzano', 'Brescia', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano']
# Mutated Route Distance: 6463.109204728523
# Child Route: ['Naples', 'Giugliano in Campania', 'Latina', 'Rome', 'Pescara', 'Trieste', 'Venice', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Verona', 'Padua', 'Vicenza', 'Trento', 'Bolzano', 'Brescia', 'Bergamo', 'Monza', 'Milan', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Forlì', 'Ravenna', 'Rimini', 'Ancona', 'Perugia', 'Terni', 'Sassari', 'Cagliari', 'Palermo', 'Catania', 'Syracuse', 'Reggio di Calabria', 'Messina', 'Taranto', 'Bari', 'Andria', 'Foggia', 'Salerno', 'Naples']
# Child Route Distance: 4512.216241182779
#
# --- Best Solution Found ---
# Best Route: ["Reggio nell'Emilia", 'Modena', 'Bologna', 'Ferrara', 'Venice', 'Trieste', 'Pescara', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Syracuse', 'Catania', 'Palermo', 'Cagliari', 'Sassari', 'Terni', 'Perugia', 'Ancona', 'Rimini', 'Ravenna', 'Forlì', 'Florence', 'Prato', 'Leghorn', 'Genoa', 'Turin', 'Novara', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Trento', 'Bolzano', 'Vicenza', 'Padua', 'Verona', 'Piacenza', 'Parma', "Reggio nell'Emilia"]
# Best Route Distance: 4505.8017130027165

# %% [markdown]
# Algorithm's Performance:
#
# -Greedy Algorithm:
# My current implementation employs a greedy algorithm to create initial routes. Greedy algorithms are generally faster than exhaustive search methods since they construct solutions step-by-step, choosing the locally optimal solution at each stage.
# However, greedy algorithms may not always yield the optimal solution for TSP, especially as the number of cities increases. They can quickly become trapped in local optima.
#
# -Genetic Algorithm (GA):
# The part of my code that includes the mutation and crossover processes is characteristic of genetic algorithms. GAs are typically slower than greedy algorithms because they involve multiple iterations, evaluating a population of solutions over many generations. They explore a broader solution space but may take longer to converge to an optimal or near-optimal solution.
